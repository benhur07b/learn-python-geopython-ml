# %% [markdown]
# # geemap

# %% [markdown]
# ``geemap`` is a Python package for interactive geospatial analysis and visualization with Google Earth Engine. It's great for use in notebooks such as Jupyter.

# %% [markdown]
# <div style="
#     background-color: white;
#     border: 2px solid #198754;
#     border-left: 21px solid #198754;
#     padding: 16px;
#     border-radius: 8px;
# ">
#
# <strong style="font-size:18px; color: #198754;">💡 TIP</strong>
#
# 1. geemap usually offers a better user experience than the Earth Engine Python API as it simplifies and abstracts some of the user interactions (e.g. exporting GEE data to your local machine)
# 2. geemap has great documentation at [**https://geemap.org**](https://geemap.org/)

# %%
import ee
import geemap

# %%
# Trigger the authentication flow.
ee.Authenticate()

# Initialize the library.
ee.Initialize(project='your-gee-project-here')
